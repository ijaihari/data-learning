# %% [markdown]
# # API

# %%
import requests

# %%
response = requests.get('https://httpbin.org/get')
response.text
# Out:
# '{\n  "args": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, br, zstd", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.32.3", \n    "X-Amzn-Trace-Id": "Root=1-6926a238-10aac4633b54aad85ef5cae1"\n  }, \n  "origin": "42.106.65.81", \n  "url": "https://httpbin.org/get"\n}\n'
