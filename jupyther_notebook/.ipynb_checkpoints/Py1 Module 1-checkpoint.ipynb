# %%
type("hello" == "world")
# Out:
# bool

# %%
30+20-40
# Out:
# 10

# %%
(55-5)/10
# Out:
# 5.0

# %%
(6*10)/12
# Out:
# 5.0

# %%
x = 3+2*2

# %%
print(x)
# Out:
# 7

# %%
y = (3 + 2) * 2

# %%
z = x + y

# %%
z
# Out:
# 17

# %%
11//2
# Out:
# 5

# %%
x=4

# %%
x=x/2

# %%
x
# Out:
# 2.0

# %%
name='IRON MAN'

# %%
name[3:5]
# Out:
# 'N '

# %%
name[::2]
# Out:
# 'IO A'

# %%
name[0:5:2]
# Out:
# 'IO '

# %%
len(name)
# Out:
# 8

# %%
s1 = name + "Avenger"

# %%
s1
# Out:
# 'IRON MANAvenger'

# %%
3*name
# Out:
# 'IRON MANIRON MANIRON MAN'

# %%
3*'IRON MAN'
# Out:
# 'IRON MANIRON MANIRON MAN'

# %%
3*'Iron Man '
# Out:
# 'Iron Man Iron Man Iron Man '

# %%
name='avenger'
name[1]
# Out:
# 'v'

# %%
name[:4]
# Out:
# 'aven'

# %%
name = 'avenger'
name
# Out:
# 'avenger'

# %%
name = name.upper()
name
# Out:
# 'AVENGER'

# %%
name = name.lower()
name
# Out:
# 'avenger'

# %%
a = 'I am Man'
a
# Out:
# 'I am Man'

# %%
a = a.replace('Man', 'Woman')
a
# Out:
# 'I am Woman'

# %%
name
# Out:
# 'avenger'

# %%
name.find('en')
# Out:
# 2

# %%
name.find('o')
# Out:
# -1

# %%
print(r'C:\newfolder')
# Out:
# C:\newfolder

# %%
print('C:\newfolder')
# Out:
# C:
# ewfolder

# %%
name = "The BodyGuard"
split_string = (name.split())
split_string
# Out:
# ['The', 'BodyGuard']
