# %%
type("hello" == "world")
# Out:
# bool

# %%
30+20-40
# Out:
# 10

# %%
(55-5)/10
# Out:
# 5.0

# %%
(6*10)/12
# Out:
# 5.0

# %%
x = 3+2*2

# %%
print(x)
# Out:
# 7

# %%
y = (3 + 2) * 2

# %%
z = x + y

# %%
z
# Out:
# 17

# %%
11//2
# Out:
# 5

# %%
x=4

# %%
x=x/2

# %%
x
# Out:
# 2.0

# %%
name='IRON MAN'

# %%
name[3:5]
# Out:
# 'N '

# %%
name[::2]
# Out:
# 'IO A'

# %%
name[0:5:2]
# Out:
# 'IO '

# %%
len(name)
# Out:
# 8

# %%
s1 = name + "Avenger"

# %%
s1
# Out:
# 'IRON MANAvenger'

# %%
3*name
# Out:
# 'IRON MANIRON MANIRON MAN'

# %%
3*'IRON MAN'
# Out:
# 'IRON MANIRON MANIRON MAN'

# %%
3*'Iron Man '
# Out:
# 'Iron Man Iron Man Iron Man '

# %%
name='avenger'
name[1]
# Out:
# 'v'

# %%
name[:4]
# Out:
# 'aven'

# %%
name = 'avenger'
name
# Out:
# 'avenger'

# %%
name = name.upper()
name
# Out:
# 'AVENGER'

# %%
name = name.lower()
name
# Out:
# 'avenger'

# %%
a = 'I am Man'
a
# Out:
# 'I am Man'

# %%
a = a.replace('Man', 'Woman')
a
# Out:
# 'I am Woman'

# %%
name
# Out:
# 'avenger'

# %%
name.find('en')
# Out:
# 2

# %%
name.find('o')
# Out:
# -1

# %%
print(r'C:\newfolder')
# Out:
# C:\newfolder

# %%
print('C:\newfolder')
# Out:
# C:
# ewfolder

# %%
name = "The BodyGuard"
split_string = (name.split())
split_string
# Out:
# ['The', 'BodyGuard']

# %% [markdown]
# # Tuples

# %%
t = (1, 2, (3, 4, 5), 6)
t[0]
# Out:
# 1

# %%
t[1]
# Out:
# 2

# %%
t[2]
# Out:
# (3, 4, 5)

# %%
t[2][:2] # ( 0, 1, 2 )
# Out:
# (3, 4)

# %%
t[3]
# Out:
# 6

# %%
t = (1, ('second', 3), 4)

# %%
t[1][0][2]
# Out:
# 'c'

# %%
t = (1, 2, (3, 4, 5), 6)
l1 = list(t)
l1
# Out:
# [1, 2, (3, 4, 5), 6]

# %%
l1[0] = 99
t = tuple(l1)

# %%
t
# Out:
# (99, 2, (3, 4, 5), 6)

# %% [markdown]
# # Quiz

# %%
genres_tuple = ("pop", "rock", "soul", "hard rock", "soft rock", \
                "R&B", "progressive rock", "disco") 
genres_tuple
# Out:
# ('pop',
#  'rock',
#  'soul',
#  'hard rock',
#  'soft rock',
#  'R&B',
#  'progressive rock',
#  'disco')

# %%
len(genres_tuple)
# Out:
# 8

# %%
genres_tuple[3]
# Out:
# 'hard rock'

# %%
genres_tuple[3:6]
# Out:
# ('hard rock', 'soft rock', 'R&B')

# %%
genres_tuple[0:2]
# Out:
# ('pop', 'rock')

# %%
genres_tuple[-1].index('s')
# Out:
# 2

# %%
C_tuple=(-5, 1, -3)
sorted_list = sorted(C_tuple)
sorted_list
# Out:
# [-5, -3, 1]

# %% [markdown]
# # Lists

# %%
L = ['iron man', 'mark', 50]
L
# Out:
# ['iron man', 'mark', 50]

# %%
L.extend(['avenger', 45])
L
# Out:
# ['iron man', 'mark', 50, 'avenger', 45]

# %%
L.append(['genius', 'billionare', 'philantrophist'])
L
# Out:
# ['iron man',
#  'mark',
#  50,
#  'avenger',
#  45,
#  ['genius', 'billionare', 'philantrophist']]

# %%
L.append((35,))
L
# Out:
# ['iron man',
#  'mark',
#  50,
#  'avenger',
#  45,
#  ['genius', 'billionare', 'philantrophist'],
#  (35,)]

# %%
L[-1][0]
# Out:
# 35

# %%
L = ['ironman']
L
# Out:
# ['ironman']

# %%
L.append('mark 50')
L
# Out:
# ['ironman', 'mark 50']

# %%
L[0] = 'mark 2'
L
# Out:
# ['mark 2', 'mark 50']

# %%
L[0].split()
# Out:
# ['mark', '2']

# %%
 a_list = [1, 'hello', [1, 2, 3], True]
a_list
# Out:
# [1, 'hello', [1, 2, 3], True]

# %%
a_list[1]
# Out:
# 'hello'

# %%
a_list[1:4]
# Out:
# ['hello', [1, 2, 3], True]

# %%
A = [1, 'a']
B = [2, 1, 'd']

# %%
A + B
# Out:
# [1, 'a', 2, 1, 'd']

# %%
A = [1]
A.append([2, 3, 4, 5])
A
# Out:
# [1, [2, 3, 4, 5]]

# %%
len(A)
# Out:
# 2

# %% [markdown]
# # Scenario: Shopping List

# %%
Shopping_list =[] # empty array created

# %%
Shopping_list = ["Watch", "Laptop", "Shoes", "Pen", "Clothes"]

# %%
Shopping_list.append("Football")

# %%
Shopping_list[0]
# Out:
# 'Watch'

# %%
Shopping_list[-1]
# Out:
# 'Football'

# %%
print(Shopping_list)
# Out:
# ['Watch', 'Laptop', 'Shoes', 'Pen', 'Clothes', 'Football']

# %%
Shopping_list[1:3]
# Out:
# ['Laptop', 'Shoes']

# %%
Shopping_list[3] = "Notebook"  # Mutable

# %%
del(Shopping_list[-2])

# %%
Shopping_list
# Out:
# ['Watch', 'Laptop', 'Shoes', 'Football']

# %%
len(Shopping_list)
# Out:
# 4
